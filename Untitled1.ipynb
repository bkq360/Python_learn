# %% [markdown]
# ### 1.Vite
#
# #### 1.install npm
# #### 2.npm create vite@latest my-vue-app -- --template vue       //npm >=7.0
# #### 3.npm intall
# #### 4.npm run dev

# %% [markdown]
# ## 2.生命周期

# %% [markdown]
# ![image.png](attachment:186ccd17-b60b-483c-b593-522455eeb7e2.png)
